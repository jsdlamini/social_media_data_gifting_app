# %% [markdown]
# # Generate Anonymous Facebook posts and comments data

# %%
# import nltk
# nltk.download('punkt')
# nltk.download('stopwords')
# import numpy as np

# nltk.download('vader_lexicon')
# import json
# import nltk
# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize
# from textblob import TextBlob
# from collections import Counter
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud
# from nltk.sentiment import SentimentIntensityAnalyzer
# # ```

# #### Step 1: Preprocess Data

# # This involves tokenizing the text and removing stop words.

# # ```python
# import json
# import nltk
# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize
# from textblob import TextBlob
# from collections import Counter
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud
# from nltk.sentiment import SentimentIntensityAnalyzer

# def load_data_v2(file_path):
#     with open(file_path, 'r') as f:
#         data = json.load(f)
#     comments = [entry['data'][0]['comment']['comment'] for entry in data['comments_v2']]
#     return comments

# def preprocess_texts(texts):
#     stop_words = set(stopwords.words('english'))
#     cleaned_texts = []
#     for text in texts:
#         # Tokenize the text into words
#         words = word_tokenize(text.lower())
#         # Filter out stop words
#         filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
#         cleaned_texts.append(' '.join(filtered_words))
#     return cleaned_texts

# # Load your data from the JSON file
# file_path = 'comments.json'  # Replace with your actual file path
# comments_texts = load_data_v2(file_path)
# cleaned_comments_texts = preprocess_texts(comments_texts)
# # ```

# #### Step 2: Sentiment Analysis

# # Perform sentiment analysis on the preprocessed text.

# # ```python
# def analyze_sentiment(texts):
#     sentiments = {'polarity': [], 'subjectivity': [], 'nltk_vader': []}
#     sia = SentimentIntensityAnalyzer()
#     for text in texts:
#         blob = TextBlob(text)
#         polarity, subjectivity = blob.sentiment.polarity, blob.sentiment.subjectivity
#         sentiments['polarity'].append(polarity)
#         sentiments['subjectivity'].append(subjectivity)
#         vader_score = sia.polarity_scores(text)['compound']
#         sentiments['nltk_vader'].append(vader_score)
#     return sentiments

# # Perform sentiment analysis on cleaned comments
# comment_sentiments = analyze_sentiment(cleaned_comments_texts)
# avg_comment_polarity = sum(comment_sentiments['polarity']) / len(comment_sentiments['polarity'])
# # ```

# #### Step 3: Generate Word Cloud

# # ```python
# def generate_word_cloud(texts, title):
#     all_text = ' '.join(texts)
#     wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110, background_color='white').generate(all_text)
#     plt.figure(figsize=(10, 5))
#     plt.imshow(wordcloud, interpolation="bilinear")
#     plt.axis('off')
#     plt.title(title)
#     plt.show()

# # Generate a word cloud for cleaned comments
# generate_word_cloud(cleaned_comments_texts, 'Word Cloud for Cleaned Comments')
# # ```

# #### Step 4: Common Words

# # ```python
# def common_words(texts, n=10):
#     all_words = ' '.join(texts).split()
#     most_common = Counter(all_words).most_common(n)
#     return most_common

# common_comment_words = common_words(cleaned_comments_texts)
# # ```

# #### Step 5: Plot Analysis

# # ```python
# def plot_bar_graphs( avg_comment_length, max_comment_length):
#     labels = ['Comments']
#     # polarity = [avg_comment_polarity]
#     avg_length = [avg_comment_length]
#     max_length = [max_comment_length]

#     x = np.arange(len(labels))  # the label locations
#     width = 0.25  # the width of the bars

#     fig, ax = plt.subplots(figsize=(10, 5))

#     # rects1 = ax.bar(x - width, polarity, width, label='Polarity', color='royalblue')
#     rects2 = ax.bar(x, avg_length, width, label='Avg Length', color='seagreen')
#     rects3 = ax.bar(x + width, max_length, width, label='Max Length', color='darkorange')

#     ax.set_ylabel('Scores')
#     ax.set_title('Sentiment and Length Metrics for Comments')
#     ax.set_xticks(x)
#     ax.set_xticklabels(labels)
#     ax.legend()

#     plt.show()



# def plot_bar_polarity_graphs( avg_comment_polarity):
#     labels = ['Comments']
#     polarity = [avg_comment_polarity]

#     x = np.arange(len(labels))  # the label locations
#     width = 0.25  # the width of the bars

#     fig, ax = plt.subplots(figsize=(10, 5))

#     rects1 = ax.bar(x - width, polarity, width, label='Polarity', color='royalblue')

#     ax.set_ylabel('Scores')
#     ax.set_title('Sentiment and Length Metrics for Comments')
#     ax.set_xticks(x)
#     ax.set_xticklabels(labels)
#     ax.legend()

#     plt.show()



# def plot_common_words(common_words, title):
#     words, counts = zip(*common_words)
#     plt.figure(figsize=(10, 5))
#     plt.bar(words, counts, color='skyblue')
#     plt.title(title)
#     plt.ylabel('Frequency')
#     plt.xticks(rotation=45)
#     plt.tight_layout()
#     plt.show()

# # Calculate average and max length of cleaned comments
# comment_lengths = [len(text.split()) for text in cleaned_comments_texts]
# avg_comment_length = sum(comment_lengths) / len(comment_lengths)
# max_comment_length = max(comment_lengths)

# # Plotting
# plot_bar_graphs(avg_comment_length, max_comment_length)
# plot_bar_polarity_graphs(avg_comment_polarity)
# plot_common_words(common_comment_words, "Common Words in Cleaned Comments")

# %%
# !pip install streamlit
# !apt-get install -qq curl
# !curl -sL https://deb.nodesource.com/setup_10.x | bash -
# !apt-get install -qq nodejs
# !npm install -g localtunnel
# !pip install streamlit pandas nltk textblob wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !pip install altair

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/zindi/DIGIMATICS'
# /content

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/zindi/DIGIMATICS
# Out:
# /content/drive/MyDrive/zindi/DIGIMATICS

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# your url is: https://rotten-monkeys-search.loca.lt
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.107.124:8501
#
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
# prompt: How do access the streamlit app url from  colab

# !pip install pyngrok

from pyngrok import ngrok

# ... (Your existing code) ...

# Get a public URL for the Streamlit app
public_url = ngrok.connect(port='8501')
print(f"Your Streamlit app is available at: {public_url}")

# ... (Rest of your code) ...
# Out:
# ...
# ERROR:pyngrok.process.ngrok:t=2024-10-17T13:57:21+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2024-10-17T13:57:21+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# <ipython-input-1-9a3ea39da64d> in <cell line: 10>()
#       8
# ...

# %%
# !pip freeze > requirements.txt

# %%
# prompt: install python packages from requirements.txt via a terminal

# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 56.5 MB/s eta 0:00:00
# Processing /colabtools/dist/google_colab-1.0.0.tar.gz (from -r requirements.txt (line 153))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/colabtools/dist/google_colab-1.0.0.tar.gz'

# %%
# !pip install -r requirements.txt
